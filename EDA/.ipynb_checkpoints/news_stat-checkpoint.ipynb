# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

from jupyterthemes import jtplot
jtplot.style()

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

import os
import json
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook
from datetime import datetime
from matplotlib import pyplot as plt
# %matplotlib inline

target_stocks = ['BANPU','IRPC','PTT','BBL','KBANK','SCB','AOT','THAI','CPF','MINT
                 'TU','SCC','CPN','CK','CPALL','HMPRO','BDMS','BH','ADVANC','JAS','TRUE',]
# Out:
# <style>.container { width:95% !important; }</style>
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
with open('../data/kaohoon.json') as json_data:
    data = json.load(json_data)
len(data)
# Out:
# 75583

# %%
data[20]
# Out:
# {'Content': 'นาย ปิติ พงศ์ พิศาล บุตร กรรมการ ผู้อำนวยการ บริษัท นว กิจ ประกันภัย จำกัด มหาชน หรือ เปิดเผย ว่า บริษัท ได้ ขาย หุ้น บริษัท ฟอ ล คอน ประกันภัย จำกัด มหาชน บริษัท ร่วม จำนวน หุ้น หรือ คิด เป็น ของ ทุนจดทะเบียน ชำระ แล้ว ให้ กับ ผู้ถือหุ้น เดิม ของ บริษัท ร่วม ที่ ราคา หุ้น ละ บาท หรือ คิด เป็น มูลค่า การซื้อขาย ทั้งสิ้น บาท ทั้งนี้ บริษัท ถือหุ้น บริษัท ร่วม ใน สัดส่วน ของ ทุนจดทะเบียน ชำระ แล้ว ของ บริษัท ร่วม',
#  'Content id': '221',
#  'Date': '2015-01-16T00:00:00',
#  'Intro': 'ขาย หุ้น ฟอ ล คอน ประกันภัย บริษัท ร่วม ให้ ผู้ถือหุ้น เดิม มูลค่า ลบ',
#  'Link': 'https://www.kaohoon.com/content/221',
#  'Source': 'Kaohoon',
#  'Stock Include': ['NKI'],
#  'Title': 'ขาย หุ้น ฟอ ล คอน ประกันภัย ให้ ผู้ถือหุ้น เดิม ข่าว หุ้น ธุรกิจ ออนไลน์'}

# %%
entry = []
for i, row in tqdm_notebook(enumerate(data)):
    if len(row['Stock Include']) > 1: continue
    for stock in row['Stock Include']:
        if stock in target_stocks:
            entry.append([
                row['Date'],
                stock,
#                 row['Stock Include'],
                row['Content']
            ])

# %%
df = pd.DataFrame.from_records(entry)
df[0] = pd.to_datetime(df[0], format='%Y-%m-%d')
df
# Out:
#               0      1                                                  2
# 0    2015-01-16    SCC  บริษัท ปูนซิเมนต์ ไทย จำกัด มหาชน หรือ เปิดเผย...
# 1    2015-01-16  KBANK  คณะกรรมการ ธนาคาร กสิกร ไทย จำกัด มหาชน หรือ ร...
# 2    2015-01-18   MINT  วิลเลียม อี ไฮ เนคกี้ ตำนาน ผู้สร้าง ธุรกิจ จา...
# 3    2015-01-19    SCC  บล เอเซีย พลัสระ บุ ใน บท วิเคราะห์ มค ว่า ภาพ...
# 4    2015-01-19    SCB  นาง ช วิน ดา หาญ รัต นกู ลก ร รม การ ผู้จัดการ...
# 5    2015-01-20    SCB  ธนาคาร ไทย พาณิชย์ จำกัด มหาชน หรือ รายงาน ผลก...
# 6    2015-01-19    PTT  นา ยธ น เดช รังาธ นา นนท์ ผู้อำนวยการ ฝ่าย วิเ...
# 7    2015-01-20    SCC  บลเค จี ไอ ประเทศไทย ระบุ ใน บทวิเคราะห์ วัน น...
# 2136 2018-01-15    BBL  ธนาคาร กรุง เทพ จำกัด มหาชน หรือ ร่วมกับ บริษั...
# 2137 2018-01-16    BBL  บลฟินัน เซีย ไซ รัสระ บุ ใน บทวิเคราะห์ วัน นี...
# 2138 2018-01-17   TRUE  บริษัท ท รู คอร์ปอเรชั่น จำกัด มหาชน หรือ เตือ...
# 2139 2018-01-17  KBANK  ผู้สื่อข่าว รายงาน ว่า วัน นี้ ม คมี รายการ สร...
# 2140 2018-01-18    BBL  ข่าว หุ้น ธุรกิจ ออนไลน์ ได้ ทำการ สำรวจ ข้อมู...
# 2141 2018-01-18    CPF  บริษัท เจริญ โภคภัณฑ์ อาหาร จำกัด มหาชน หรือ ร...
# 2142 2018-01-18    CPF  นาย สุขสันต์ เจียม ใจ สว่าง ฤกษ์ นั่ง กลาง ประ...
# 2143 2018-01-18     BH  ผู้สื่อข่าว รายงาน ว่า วัน นี้ ม คมี รายการ สร...
# 2144 2018-01-18   MINT  เคลื่อนไหว อยู่ ระหว่าง และ ปิด ตลาด ใน ช่วง เ...
# 2145 2018-01-19    BBL  ธนาคาร กรุง เทพ จำกัด มหาชน หรือ รายงาน ผลการด...
# 2146 2018-01-19    SCB  ผู้สื่อข่าว รายงาน ว่า ราคา หุ้น ธนาคาร ไทย พา...
# 2147 2018-01-19  KBANK  ธนาคาร กสิกร ไทย จำกัด มหาชน หรือ รายงาน ผลการ...
# 2148 2018-01-19  KBANK  ผู้สื่อข่าว รายงาน ว่า ราคา หุ้น ธนาคาร กสิกร ...
# 2149 2018-01-22    SCC  บริษัท ปูนซิเมนต์ ไทย จำกัด มหาชน หรือ ระบุ ว่...
# 2150 2018-01-23  KBANK  บล โน มูระพัฒน สิ นระ บุ ใน บทวิเคราะห์ วัน นี...
# 2151 2018-01-24   BDMS  ผู้สื่อข่าว รายงาน ว่า วัน นี้ ม คมี รายการ สร...
# 2152 2018-01-24    SCC  บริษัท ปูนซิเมนต์ ไทย จำกัด มหาชน หรือ รายงาน ...
# 2153 2018-01-25  KBANK  ผู้สื่อข่าว รายงาน ว่า วันนี้ มี รายการ สรุป ซ...
# 2154 2018-01-25  KBANK  ผู้สื่อข่าว รายงาน ว่า วันนี้ มี รายการ สรุป ซ...
# 2155 2018-01-26    PTT  บริษัท สากล เอน เนอ ยี จำกัด มหาชน หรือ เปิดเผ...
# 2156 2018-01-30    SCB  จาก กรณี เมื่อ วัน ที่ มค ที่ผ่านมา นาย ไว ทิต...
# 2157 2018-01-30    CPF  นาย ชัย ยุทธ ทิพย์ สุ วรรณ พร รอง กรรมการผู้จั...
# 2158 2018-02-01   BDMS  เคลื่อนไหว อยู่ ระหว่าง และ ปิด ตลาด ใน ช่วง เ...
# 2159 2018-02-01  KBANK  สำนักงาน คณะกรรมการ กำกับ หลักทรัพย์ และ ตลาดห...
# 2160 2018-02-05    CPF  บริษัท เจริญ โภคภัณฑ์ อาหาร จำกัด มหาชน หรือ จ...
# 2161 2018-02-06  KBANK  นาย ศีล วัต สัน ติวิสัฎฐ์ นั่ง ขวา รอง กรรมการ...
#
# [2162 rows x 3 columns]
